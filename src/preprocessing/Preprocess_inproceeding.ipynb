# %%
import pandas as pd
import numpy as np

INPROCEEDING_TO_KEEP = 1000
FILE_PATH = 'C:/Users/Alex/Desktop/Jim Profile/Studies/BDMA/Courses/Semantic Data Management/lab1/dataset/dblp-2019-11-01-csv/'

inproceedings = pd.read_csv(FILE_PATH+'output_inproceedings_first4k.csv', sep=';', header=None, error_bad_lines=False)
inproceedings_header = pd.read_csv(FILE_PATH+'output_inproceedings_header.csv', sep=';')
inproceedings_cols = [x[:x.find(':')] for x in inproceedings_header.columns]
inproceedings.columns = inproceedings_cols

# inproceedings_new includes only conferences
inproceedings_new = inproceedings[inproceedings.key.str.contains('conf/',case=False)]
inproceedings_new.dropna(subset = ["crossref"], inplace=True)
#inproceedings_new["booktitle"].unique()

inproceedings_new = inproceedings_new[['key','booktitle','author','crossref','title','year']]

# keep first N
inproceedings_new = inproceedings_new.head(INPROCEEDING_TO_KEEP)
inproceedings_new
# Out:
# C:\Users\Alex\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            key booktitle  \
# 57       conf/nooj/HammoudaH16      NooJ
# 58          conf/nooj/Watabe17      NooJ
# 59        conf/nooj/GottiMGL17      NooJ
# 60    conf/nooj/BlancheteMMM18      NooJ
# 61        conf/nooj/Machonis16      NooJ
# ...                        ...       ...
# 1052   conf/issac/FaugereMRD08     ISSAC
# 1053      conf/issac/BihanRS09     ISSAC
# 1054      conf/issac/GerdtKZ90     ISSAC
# 1055        conf/issac/Brown15     ISSAC
# 1056      conf/issac/WangKZZ03     ISSAC
#
#                                                  author         crossref  \
# 57                  Kais Haddar|Nadia Ghezaiel Hammouda   conf/nooj/2016
# 58                                        Masako Watabe   conf/nooj/2017
# 59      Naziha Laaz|Samir Mbarki|Sara Gotti|Zineb Gotti   conf/nooj/2017
# 60    Abdelaziz Mouloudi|Ilham Blanchete|Mohammed Mo...   conf/nooj/2018
# 61                                    Peter A. Machonis   conf/nooj/2016
# ...                                                 ...              ...
# 1052  Fabrice Rouillier|Guillaume Moroz|Jean-Charles...  conf/issac/2008
# 1053  Casey E. Stella|Fr̩d̩ric Bihan|J. Maurice Rojas  conf/issac/2009
# 1054   A. Yu. Zharkov|N. V. Khutornoy|Vladimir P. Gerdt  conf/issac/1990
# 1055                               Christopher W. Brown  conf/issac/2015
# 1056       Norbert Kajler|Paul S. Wang|Xiao Zou|Yi Zhou  conf/issac/2003
#
#                                                   title  year
# 57    Integration of a Segmentation Tool for Arabic ...  2016
# 58    A NooJ Dictionary for the Rromani Language: To...  2017
# 59        Nooj Graphical User Interfaces Modernization.  2017
# 60    Arabic Broken Plural Generation Using the Extr...  2018
# 61    Phrasal Verb Disambiguation Grammars: Cutting ...  2016
# ...                                                 ...   ...
# 1052  Classification of the perspective-three-point ...  2008
# 1053  Faster real feasibility via circuit discrimina...  2009
# 1054  Solving Algebraic Systems which Arise as Neces...  1990
# 1055  Open Non-uniform Cylindrical Algebraic Decompo...  2015
# 1056      WME: towards a web for mathematics education.  2003
#
# [1000 rows x 6 columns]

# %%
papers = inproceedings_new[['key','booktitle','crossref','title','year']]



# remove conf/ from key
inproceedings_new['key'].replace(regex=True,inplace=True,to_replace=r'conf/',value=r'')

# write to file
inproceedings_new.to_csv(r'C:\Users\Alex\Desktop\Jim Profile\Studies\BDMA\Courses\Semantic Data Management\lab1\dataset\dblp-2019-11-01-csv\Proceddings.csv')

# create editions
editions = inproceedings_new[['key','booktitle','year']]
# write to file
editions.to_csv(r'C:\Users\Alex\Desktop\Jim Profile\Studies\BDMA\Courses\Semantic Data Management\lab1\dataset\dblp-2019-11-01-csv\Edition.csv')

# create conferences
conferences = inproceedings_new['booktitle'].unique()
with open(FILE_PATH+'Conferences.csv', 'a') as the_file:
    for j in conferences:
        the_file.write(j+'\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2d97641c1aba> in <module>
# ----> 1 inproceedings_new = inproceedings_new[['key','booktitle','isbn','mdate','publisher','title','year']]
#       2
#       3
#       4
#       5 # remove conf/ from key
#
# NameError: name 'inproceedings_new' is not defined
