# %%
import pandas as pd
import numpy as np

FILE_PATH = 'C:/Users/webma/Desktop/BDMA/UPC/Semantic Data Management/Labs/Lab1/Dataset/'

# %%
data = pd.read_csv(FILE_PATH+'output_article.csv', sep=';', header=None)
header = pd.read_csv(FILE_PATH+'output_article_header.csv', sep=';')
data.columns = [x[:x.find(':')] for x in header.columns]
data.head(10)
# Out:
# C:\Users\webma\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (2,4,5,6,7,8,9,10,11,13,14,18,19,20,21,22,23,24,28,29,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    article                                             author author-aux  \
# 0    91701                                                NaN        NaN
# 1    91702                                                NaN        NaN
# 2    91703                                                NaN        NaN
# 3  2480033                                       Frank Manola        NaN
# 4  2480034  Alejandro P. Buchmann|Frank Manola|Mark F. Hor...        NaN
# 5  2480035                                       Frank Manola        NaN
# 6  2480036     Farshad Nayeri|Joe D. Morrison|Mark F. Hornick        NaN
# 7  2480037                                       Frank Manola        NaN
# 8  2480038                                       Frank Manola        NaN
# 9  2480039                                       Frank Manola        NaN
#
#   author-orcid booktitle cdate cdrom cite cite-label crossref  ... publisher  \
# 0          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 1          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 2          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 3          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 4          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 5          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 6          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 7          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 8          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
# 9          NaN       NaN   NaN   NaN  NaN        NaN      NaN  ...       NaN
#
#    publtype  sub  sup                                              title  \
# 0  informal  NaN  NaN                                            (error)
# 1  informal  NaN  NaN                              (was never published)
# 2  informal  NaN  NaN                                                  …
# 3  informal  NaN  NaN  Object Data Language Facilities for Multimedia...
# 4  informal  NaN  NaN  Object Data Model Facilities for Multimedia Da...
# 5  informal  NaN  NaN  An Evaluation of Object-Oriented DBMS Developm...
# 6  informal  NaN  NaN  Integrating Heterogeneous, Autonomous, Distrib...
# 7  informal  NaN  NaN  Object Model Capabilities For Distributed Obje...
# 8  informal  NaN  NaN          Distributed Object Management Technology.
# 9  informal  NaN  NaN  MetaObject Protocol Concepts for a RISC Object...
#
#   title-bibtex   tt                                              url  \
# 0          NaN  NaN                                              NaN
# 1          NaN  NaN                                              NaN
# 2          NaN  NaN                                              NaN
# 3          NaN  NaN  db/journals/gtelab/index.html#TR-0169-12-91-165
# 4          NaN  NaN  db/journals/gtelab/index.html#TM-0332-11-90-165
# 5          NaN  NaN  db/journals/gtelab/index.html#TR-0263-08-94-165
# 6          NaN  NaN  db/journals/gtelab/index.html#TR-0174-12-91-165
# 7          NaN  NaN  db/journals/gtelab/index.html#TM-0149-06-89-165
# 8          NaN  NaN  db/journals/gtelab/index.html#TM-0014-06-88-165
# 9          NaN  NaN  db/journals/gtelab/index.html#TR-0244-12-93-165
#
#               volume    year
# 0                NaN     NaN
# 1                NaN     NaN
# 2                NaN     NaN
# 3  TR-0169-12-91-165  1991.0
# 4  TM-0332-11-90-165  1990.0
# 5  TR-0263-08-94-165  1994.0
# 6  TR-0174-12-91-165  1991.0
# 7  TM-0149-06-89-165  1989.0
# 8  TM-0014-06-88-165  1988.0
# 9  TR-0244-12-93-165  1993.0
#
# [10 rows x 33 columns]

# %%
jv = data[['article','author','crossref','journal','key','title','volume','year']]
jv = jv.dropna()
jv.head(50)
# Out:
#         article                                             author  \
# 323863  5335336                         Amit Golander|Shlomo Weiss
# 323864  5335337            Michel Dubois|Seok-Jun Park|Woojin Choi
# 323865  5335338                 Dean M. Tullsen|Subhradyuti Sarkar
# 323866  5335339  Chris C. Kirkham|Christos Kotselidis|Ian Watso...
# 323868  5335342                                    M. M. Waliullah
# 323869  5335343  François Bodin|Marcelo Cintra|Michael F. P. O'...
# 323870  5335344  Ben Cope|Lee W. Howes|Peter Y. K. Cheung|Wayne...
# 323871  5335345    Thambipillai Srikanthan|Wu Jigang|Xiongfei Liao
# 323872  5335346                             Omer Khan|Sandip Kundu
# 323873  5335347  Chunyuan Zhang|Ju Ren|Maolin Guan|Mei Wen|Nan ...
# 323874  5335348                Frederik Vandeputte|Lieven Eeckhout
# 323876  5335350  Chris C. Kirkham|Christos Kotselidis|Ian Watso...
# 323877  5335351        Chunling Hu|Daniel A. Jiménez|Ulrich Kremer
# 323878  5335352  Alex E. Susu|Andrea Acquaviva|David Atienza|Gi...
# 323879  5335353  Dries Buytaert|Koen De Bosschere|Kris Vensterm...
# 323880  5335354         Hamid Noori|Maziar Goudarzi|Tohru Ishihara
# 323882  5335356                Frederik Vandeputte|Lieven Eeckhout
# 323883  5335357  Antonio González 0001|Fernando Latorre|Grigori...
# 323884  5335358     Gary S. Tyson|Michael J. Geiger|Sally A. McKee
# 323885  5335360  Anca Mariana Molnos|Jos T. J. van Eijndhoven|M...
# 323886  5335361                        Dongrui Fan|Lei Yu|Nan Yuan
# 323887  5335362  Albert Cohen 0001|Grigori Fursin|Michael F. P....
# 323888  5335363  Basheer A. M. Madappuram|Liam McDaid|Peter M. ...
# 323889  5335364  Carsten Trinitis|Josef Weidendorfer|Michael Ot...
# 323890  5335366                    Chuen-Liang Chen|Chun-Chieh Lin
# 323891  5335367  Antonio González 0001|Jaume Abella|Michael F. ...
# 323893  5335369  Christopher I. Rodrigues|Matthew I. Frank|Robe...
# 323894  5335370  Axel Jantsch|Davide Bertozzi|Francesco Poletti...
# 323895  5335371                   André Seznec|Hans Vandierendonck
# 323897  5335373  Alex Ramírez|Andrei Sergeevich Terechko|Arnald...
# 323898  5335374              Mahmut T. Kandemir|Seung Woo Son 0001
# 323899  5335375                                  Maurice V. Wilkes
# 323900  5335376                                      Per Stenström
# 323901  5335377                                     Sally A. McKee
# 323902  5335378                  Leyla Nazhandali|Michael B. Henry
# 323903  5335380  José Gabriel F. Coutinho|Oskar Mencer|Wayne Lu...
# 323904  5335381  Claude Tadonki|Joel Falcou|Lionel Lacassagne|S...
# 323905  5335382  Alan Gara|Matthias A. Blumrich|Valentina Salapura
# 323906  5335383  Doug Burger|Kathryn S. McKinley|Nicholas Nethe...
# 323907  5335384  Mary Kiemb|Nimish Sane|Shuvra S. Bhattacharyya...
# 323908  5335385  Andreas Herkersdorf|Daniel Llorente|Kimon Karr...
# 323909  5335386                     Guilin Chen|Mahmut T. Kandemir
# 323910  5335387       Mahmut T. Kandemir|Sai Prashanth Muralidhara
# 323911  5335388  Alex Ramírez|Francisco J. Cazorla|Mateo Valero...
# 323912  5335389  Hiroaki Kobayashi|Hiroyuki Takizawa|Isao Koter...
# 323913  5335390  Georgios Keramidas|Polychronis Xekalakis|Stefa...
# 323914  5335391                    Lieven Eeckhout|Simon Kluyskens
# 323915  5335392                   Israel Waldman|Shlomit S. Pinter
# 323916  5335393  Diana Franklin|Frederic T. Chong|John Oliver|V...
# 323917  5335394                          Minwook Ahn|Yunheung Paek
#
#                        crossref        journal  \
# 323863  journals/thipeac/2009-2  Trans. HiPEAC
# 323864  journals/thipeac/2009-2  Trans. HiPEAC
# 323865  journals/thipeac/2011-3  Trans. HiPEAC
# 323866  journals/thipeac/2011-3  Trans. HiPEAC
# 323868  journals/thipeac/2011-3  Trans. HiPEAC
# 323869  journals/thipeac/2007-1  Trans. HiPEAC
# 323870  journals/thipeac/2011-4  Trans. HiPEAC
# 323871  journals/thipeac/2011-4  Trans. HiPEAC
# 323872  journals/thipeac/2011-4  Trans. HiPEAC
# 323873  journals/thipeac/2011-4  Trans. HiPEAC
# 323874  journals/thipeac/2011-4  Trans. HiPEAC
# 323876  journals/thipeac/2011-4  Trans. HiPEAC
# 323877  journals/thipeac/2009-2  Trans. HiPEAC
# 323878  journals/thipeac/2007-1  Trans. HiPEAC
# 323879  journals/thipeac/2007-1  Trans. HiPEAC
# 323880  journals/thipeac/2011-3  Trans. HiPEAC
# 323882  journals/thipeac/2011-4  Trans. HiPEAC
# 323883  journals/thipeac/2011-3  Trans. HiPEAC
# 323884  journals/thipeac/2007-1  Trans. HiPEAC
# 323885  journals/thipeac/2007-1  Trans. HiPEAC
# 323886  journals/thipeac/2011-4  Trans. HiPEAC
# 323887  journals/thipeac/2007-1  Trans. HiPEAC
# 323888  journals/thipeac/2011-4  Trans. HiPEAC
# 323889  journals/thipeac/2011-3  Trans. HiPEAC
# 323890  journals/thipeac/2011-3  Trans. HiPEAC
# 323891  journals/thipeac/2011-4  Trans. HiPEAC
# 323893  journals/thipeac/2007-1  Trans. HiPEAC
# 323894  journals/thipeac/2007-1  Trans. HiPEAC
# 323895  journals/thipeac/2009-2  Trans. HiPEAC
# 323897  journals/thipeac/2011-4  Trans. HiPEAC
# 323898  journals/thipeac/2007-1  Trans. HiPEAC
# 323899  journals/thipeac/2007-1  Trans. HiPEAC
# 323900  journals/thipeac/2007-1  Trans. HiPEAC
# 323901  journals/thipeac/2007-1  Trans. HiPEAC
# 323902  journals/thipeac/2011-4  Trans. HiPEAC
# 323903  journals/thipeac/2011-4  Trans. HiPEAC
# 323904  journals/thipeac/2011-3  Trans. HiPEAC
# 323905  journals/thipeac/2011-3  Trans. HiPEAC
# 323906  journals/thipeac/2007-1  Trans. HiPEAC
# 323907  journals/thipeac/2011-4  Trans. HiPEAC
# 323908  journals/thipeac/2011-4  Trans. HiPEAC
# 323909  journals/thipeac/2007-1  Trans. HiPEAC
# 323910  journals/thipeac/2011-4  Trans. HiPEAC
# 323911  journals/thipeac/2011-3  Trans. HiPEAC
# 323912  journals/thipeac/2011-3  Trans. HiPEAC
# 323913  journals/thipeac/2009-2  Trans. HiPEAC
# 323914  journals/thipeac/2009-2  Trans. HiPEAC
# 323915  journals/thipeac/2007-1  Trans. HiPEAC
# 323916  journals/thipeac/2007-1  Trans. HiPEAC
# 323917  journals/thipeac/2009-2  Trans. HiPEAC
#
#                                        key  \
# 323863        journals/thipeac/GolanderW09
# 323864           journals/thipeac/ChoiPD09
# 323865          journals/thipeac/SarkarT11
# 323866      journals/thipeac/AnsariLKJKW11
# 323868        journals/thipeac/Waliullah11
# 323869         journals/thipeac/OBoyleBC07
# 323870          journals/thipeac/CopeCLH11
# 323871           journals/thipeac/LiaoJS11
# 323872            journals/thipeac/KhanK11
# 323873         journals/thipeac/WuYWHRGZ11
# 323874     journals/thipeac/VandeputteE11a
# 323876     journals/thipeac/AnsariLKJKW11a
# 323877             journals/thipeac/HuJK09
# 323878         journals/thipeac/SusuMAAM07
# 323879      journals/thipeac/BuytaertVEB07
# 323880       journals/thipeac/GoudarziIN11
# 323882      journals/thipeac/VandeputteE11
# 323883      journals/thipeac/LatorreMGCG11
# 323884         journals/thipeac/GeigerMT07
# 323885        journals/thipeac/MolnosCHE07
# 323886           journals/thipeac/YuanYF11
# 323887        journals/thipeac/FursinCOT07
# 323888          journals/thipeac/BeiuMKM11
# 323889          journals/thipeac/KlugOWT11
# 323890             journals/thipeac/LinC11
# 323891         journals/thipeac/JonesOAG11
# 323893        journals/thipeac/RyooURKFH07
# 323894  journals/thipeac/KhatibBPBJBKHNJ07
# 323895  journals/thipeac/VandierendonckS09
# 323897   journals/thipeac/AzevedoJMTHARV11
# 323898             journals/thipeac/SonK07
# 323899           journals/thipeac/Wilkes07
# 323900        journals/thipeac/Stenstrom07
# 323901            journals/thipeac/McKee07
# 323902           journals/thipeac/HenryN11
# 323903       journals/thipeac/OsborneLCM11
# 323904      journals/thipeac/SaidaniLFTB11
# 323905       journals/thipeac/BlumrichSG11
# 323906     journals/thipeac/NethercoteBM07
# 323907      journals/thipeac/PlishkerSKB11
# 323908      journals/thipeac/LlorenteKWH11
# 323909            journals/thipeac/ChenK07
# 323910     journals/thipeac/MuralidharaK11
# 323911        journals/thipeac/MoretoCRV11
# 323912       journals/thipeac/KoteraAETK11
# 323913      journals/thipeac/KeramidasXK09
# 323914       journals/thipeac/KluyskensE09
# 323915          journals/thipeac/PinterW07
# 323916        journals/thipeac/OliverFCA07
# 323917             journals/thipeac/AhnP09
#
#                                                     title volume    year
# 323863  Reexecution and Selective Reuse in Checkpoint ...      2  2009.0
# 323864  Accurate Instruction Pre-scheduling in Dynamic...      2  2009.0
# 323865  Data Layout for Cache Performance on a Multith...      3  2011.0
# 323866  Robust Adaptation to Available Parallelism in ...      3  2011.0
# 323868  Efficient Partial Roll-Backing Mechanism for T...      3  2011.0
# 323869                            Introduction to Part 2.      1  2007.0
# 323870  A Systematic Design Space Exploration Approach...      4  2011.0
# 323871  A Modular Simulator Framework for Network-on-C...      4  2011.0
# 323872  Microvisor: A Runtime Architecture for Thermal...      4  2011.0
# 323873              Tiled Multi-Core Stream Architecture.      4  2011.0
# 323874  Finding Extreme Behaviors in Microprocessor Wo...      4  2011.0
# 323876  Transaction Reordering to Reduce Aborts in Sof...      4  2011.0
# 323877  Combining Edge Vector and Event Counter for Ti...      2  2009.0
# 323878  Reconfiguration Strategies for Environmentally...      1  2007.0
# 323879     GCH: Hints for Triggering Garbage Collections.      1  2007.0
# 323880  Software-Level Instruction-Cache Leakage Reduc...      3  2011.0
# 323882  Characterizing Time-Varying Program Behavior U...      4  2011.0
# 323883  CROB: Implementing a Large Instruction Window ...      3  2011.0
# 323884  Specializing Cache Structures for High Perform...      1  2007.0
# 323885  Static Cache Partitioning Robustness Analysis ...      1  2007.0
# 323886  An Efficient and Flexible Task Management for ...      4  2011.0
# 323887  Quick and Practical Run-Time Evaluation of Mul...      1  2007.0
# 323888  On Two-Layer Brain-Inspired Hierarchical Topol...      4  2011.0
# 323889  autopin - Automated Optimization of Thread-to-...      3  2011.0
# 323890  Cache Sensitive Code Arrangement for Virtual M...      3  2011.0
# 323891    Compiler Directed Issue Queue Energy Reduction.      4  2011.0
# 323893  Automatic Discovery of Coarse-Grained Parallel...      1  2007.0
# 323894  Hardware/Software Architecture for Real-Time E...      1  2007.0
# 323895  Fetch Gating Control through Speculative Instr...      2  2009.0
# 323897  A Highly Scalable Parallel Implementation of H...      4  2011.0
# 323898     A Prefetching Algorithm for Multi-speed Disks.      1  2007.0
# 323899                  High Performance Processor Chips.      1  2007.0
# 323900                            Introduction to Part 1.      1  2007.0
# 323901                            Introduction to Part 3.      1  2007.0
# 323902  Hybrid Super/Subthreshold Design of a Low Powe...      4  2011.0
# 323903  Energy Reduction by Systematic Run-Time Reconf...      4  2011.0
# 323904  Parallelization Schemes for Memory Optimizatio...      3  2011.0
# 323905  Exploring the Architecture of a Stream Registe...      3  2011.0
# 323906  Convergent Compilation Applied to Loop Unrolling.      1  2007.0
# 323907            Heterogeneous Design in Functional DIF.      4  2011.0
# 323908  Advanced Packet Segmentation and Buffering Alg...      4  2011.0
# 323909  An Approach for Enhancing Inter-processor Data...      1  2007.0
# 323910  Communication Based Proactive Link Power Manag...      4  2011.0
# 323911  Dynamic Cache Partitioning Based on the MLP of...      3  2011.0
# 323912   Power-Aware Dynamic Cache Partitioning for CMPs.      3  2011.0
# 323913  Recruiting Decay for Dynamic Power Reduction i...      2  2009.0
# 323914  Branch Predictor Warmup for Sampled Simulation...      2  2009.0
# 323915  Selective Code Compression Scheme for Embedded...      1  2007.0
# 323916  Using Application Bisection Bandwidth to Guide...      1  2007.0
# 323917  Fast Code Generation for Embedded Processors w...      2  2009.0

# %%
#Journal
journal=jv['journal'].unique()
with open(FILE_PATH+'bulk_csv/journal.csv', 'a') as the_file:
    for j in journal:
        the_file.write(j+'\n')

# %%
#Volume
volume=jv[['crossref','volume', 'year', 'journal']]
volume.columns = ['key', 'number', 'year', 'journal']
volume['key'].replace(regex=True,inplace=True,to_replace=r'journals/',value=r'')
volume['year']=volume['year'].astype(int)
volume['number']=volume['number'].astype(int)
volume.head(10)
volume.remove_duplicates()
volume.to_csv(FILE_PATH+'bulk_csv/volume(journal).csv', index=False)
# Out:
# C:\Users\webma\Anaconda3\lib\site-packages\pandas\core\generic.py:6786: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# C:\Users\webma\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\webma\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6b4a854f20aa> in <module>
#       6 volume['number']=volume['number'].astype(int)
#       7 volume.head(10)
# ----> 8 volume.remove_duplicates()
#       9 volume.to_csv(FILE_PATH+'bulk_csv/volume(journal).csv', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'remove_duplicates'

# %%
#Paper
paper = jv[['key', 'title', 'year', 'crossref']]
paper['key'].replace(regex=True,inplace=True,to_replace=r'journals/',value=r'')
paper['crossref'].replace(regex=True,inplace=True,to_replace=r'journals/',value=r'')
paper['year'] = paper['year'].astype(int)
paper.to_csv(FILE_PATH+'bulk_csv/paper(volume).csv', index=False)
paper.head(10)
# Out:
# C:\Users\webma\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                           key  \
# 323863  thipeac/GolanderW09
# 323864  thipeac/ChoiPD09
# 323865  thipeac/SarkarT11
# 323866  thipeac/AnsariLKJKW11
# 323868  thipeac/Waliullah11
# 323869  thipeac/OBoyleBC07
# 323870  thipeac/CopeCLH11
# 323871  thipeac/LiaoJS11
# 323872  thipeac/KhanK11
# 323873  thipeac/WuYWHRGZ11
#
#                                                                                                                                       title  \
# 323863  Reexecution and Selective Reuse in Checkpoint Processors.
# 323864  Accurate Instruction Pre-scheduling in Dynamically Scheduled Processors.
# 323865  Data Layout for Cache Performance on a Multithreaded Architecture.
# 323866  Robust Adaptation to Available Parallelism in Transactional Memory Applications.
# 323868  Efficient Partial Roll-Backing Mechanism for Transactional Memory Systems.
# 323869  Introduction to Part 2.
# 323870  A Systematic Design Space Exploration Approach to Customising Multi-Processor Architectures: Exemplified Using Graphics Processors.
# 323871  A Modular Simulator Framework for Network-on-Chip Based Manycore Chips Using UNISIM.
# 323872  Microvisor: A Runtime Architecture for Thermal Management in Chip Multiprocessors.
# 323873  Tiled Multi-Core Stream Architecture.
#
#         year        crossref
# 323863  2009  thipeac/2009-2
# 323864  2009  thipeac/2009-2
# 323865  2011  thipeac/2011-3
# 323866  2011  thipeac/2011-3
# 323868  2011  thipeac/2011-3
# 323869  2007  thipeac/2007-1
# 323870  2011  thipeac/2011-4
# 323871  2011  thipeac/2011-4
# 323872  2011  thipeac/2011-4
# 323873  2011  thipeac/2011-4

# %%
#Author
author = jv[['key','author']]
author['key'].replace(regex=True,inplace=True,to_replace=r'journals/',value=r'')
new_author = pd.DataFrame(author.author.str.split('|').tolist(), index=author.key).stack()
new_author = new_author.reset_index([0, 'key'])
new_author.columns = ['key', 'author']
new_author.to_csv(FILE_PATH+'bulk_csv/author(paper).csv', index=False)
